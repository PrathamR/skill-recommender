# %% [markdown]
# # Designing a path for career conversion
# ### Prathamesh Karve

# %% [markdown]
# ## Import necessary libraries

# %%
import os
import json
import pandas as pd

# %% [markdown]
# ## Load the scraped profiles in pandas dataframe

# %%
path_to_json = '.'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
jsons_data = pd.DataFrame(columns=['name','is_intern','positions','educations','skills'])

# %% [markdown]
# ### Data cleaning

# %%
# Function to detect acronym in skill name and discard the full name
def keepShorter(skill):
    inner = None
    if '(' in skill:
        inner  = skill.split('(', 1)[1].split(')')[0]
        before = skill.split('(')[0]
    
    if(inner):
        return before if len(before) < len(inner) else inner
    else:
        return skill
    
    print(skill)
    regPar = r'\(([^)]+)'
    match  = re.search('\(([^)]+)', skill)
    if(match):
        outer  = match.group(0)
        inner  = match.group(1)
        third  = match.group(2)
        print(inner, outer, third)
        
    else:
        return skill

for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text   = json.load(json_file)
        
        name        = json_text['profile']['name']
        
        # Scan the headline to determine if the person is Intern or not
        is_intern   =  1 if ('Intern ' in json_text['profile']['headline']) else 0
        
        positions   = json_text['positions'][0]
        educations  = json_text['educations']
        
        # Process the skills json object to retain only a dictionary of skills
        skills_dict = {}
        for skill in json_text['skills']:
            if('count' in skill):
                skills_dict[skill['title']] = int(skill['count']) + 1
            else:
                skills_dict[skill['title']] = 1
                
        # Convert all the skills to lowercase (NodeJS == nodejs)
        skills_dict = {k.lower() : v for k,v in skills_dict.items()}
         
        # Remove all whitespaces (node js == nodejs)
        skills_dict = {k.translate({32:None}) : v for k,v in skills_dict.items()}
        
        # Remove all hyphens (tcp-ip == tcpip)
        skills_dict = {k.translate({45:None}) : v for k,v in skills_dict.items()}
        
        # Remove all dots (node.js == nodejs)
        skills_dict = {k.translate({46:None}) : v for k,v in skills_dict.items()}
        
        # Keep only acronyms (amazonwebservices(aws) === aws)
        skills_dict = {keepShorter(k) : (v + (skills_dict[keepShorter(k)] if keepShorter(k) in skills_dict else 0)) for k,v in skills_dict.items()}
        
        # Add the processed skills to data frame
        skills = skills_dict
                
        jsons_data.loc[index] = [name, is_intern, positions, educations, skills]
        
print(jsons_data)
# Out:
#                        name is_intern  \
# 0              Saumya          1
# 1               Sreya          0
# 2             Maithili          0
# 3               Vaidehi          0
# 4              Amruta          1
# 5            Sweety          1
# 6                 Kriti          1
# 7                Riti          1
# 8         Apoorv          0
# 9               Pooja          0
# 10       Anusha          0
# 11            Rajas          1
# 12            Nikita          0
# 13             Varsha          0
# 14          Akanksha          0
# 15      Chandni          0
# 16            Poonam          0
# 17          Kunal          1
# 18              Mayur          1
# 19          Nandini          1
# 20                Yash          1
# 21              Neha          1
# 22       Bhaumik          0
# 23           Diksha          0
# 24        Nayana          1
# 25      Deepika          0
# 26          Rachel          0
# 27             Supriya          1
# 28           Akhilesh          1
# 29            Zach          0
# 30         Priyanka          0
# 31        Priyanka          1
# 32            Devika          1
# 33                 Jacky C.         1
# 34          Anna          0
# 35                 Het          1
# 36            Nikki          0
# 37              Ashna          0
# 38            Saket          1
# 39               Ishan          0
# 40               Yanki          0
# 41            Nrupa          1
# 42             Anoop          1
# 43           Akshay          0
# 44         Sphoorti          0
# 45   Chandhini          0
# 46         Sowmya          0
# 47             Ashish          1
# 48  Venkateswara           0
# 49      Sandhya          1
# 50        Gayathri          0
# 51         Smitha          0
# 52             Kathan          0
# 53      Pratiksha          0
# 54         AISHWARIYA          0
# 55               Ramya          0
# 56           Swathi          0
# 57         Prathamesh          0
# 58          Pooja          0
# 59             Aditya          0
#
#                                             positions  \
# 0   {'title': 'Software Engineer Intern', 'company...
# 1   {'title': 'Associate Software Engineer', 'comp...
# 2   {'title': 'Software Engineer', 'companyName': ...
# 3   {'title': 'Software Engineer ll', 'companyName...
# 4   {'title': 'Software Engineer Intern', 'company...
# 5   {'title': 'IT Intern', 'companyName': 'Pure St...
# 6   {'title': 'Software Engineer Intern', 'company...
# 7   {'title': 'SWE Intern II', 'companyName': 'Goo...
# 8   {'title': 'Senior Engineer', 'companyName': 'R...
# 9   {'title': 'Software Developer', 'companyName':...
# 10  {'title': 'Application Engineer', 'companyName...
# 11  {'title': 'Software Development Engineer Inter...
# 12  {'title': 'Siri Software Engineer', 'companyNa...
# 13  {'title': 'Research Engineer', 'companyName': ...
# 14  {'title': 'Adobe', 'description': '- Building ...
# 15  {'title': 'Application Engineer', 'companyName...
# 16  {'title': 'Software Engineer', 'companyName': ...
# 17  {'title': 'Frontend Software Engineer Intern',...
# 18  {'title': 'Software Engineer Intern', 'company...
# 19  {'title': 'Embedded Engineer Intern', 'company...
# 20  {'title': 'Software Engineer Intern', 'company...
# 21  {'title': 'Software Developer Engineer Intern'...
# 22  {'title': 'Software Engineer Intern- Tools and...
# 23  {'title': 'Software Engineer', 'companyName': ...
# 24  {'title': 'Engineering Intern', 'companyName':...
# 25  {'title': 'Software Engineer', 'companyName': ...
# 26  {'title': 'Chief Product Officer', 'companyNam...
# 27  {'title': 'Software Engineer Intern', 'company...
# 28  {'title': 'Software Engineer Intern', 'company...
# 29  {'title': 'Freelance Developer', 'companyName'...
# 30  {'title': 'Microsoft', 'date1': 'Mar 2019 – Pr...
# 31  {'title': 'Software Developer Intern', 'compan...
# 32  {'title': 'Software Engineering Intern', 'comp...
# 33  {'title': 'Software Engineer Intern', 'company...
# 34  {'title': 'Software Engineer', 'companyName': ...
# 35  {'title': 'Quality Engineering Intern', 'compa...
# 36  {'title': 'NPI, Engineering & Programs', 'comp...
# 37  {'title': 'UX Design and Developer for cloud i...
# 38  {'title': 'Software Engineering Intern II', 'c...
# 39  {'title': 'Teaching Assistant', 'companyName':...
# 40  {'title': 'Software Engineer 2', 'companyName'...
# 41  {'title': 'Software Engineer Intern', 'company...
# 42  {'title': 'Software Developer Intern', 'compan...
# 43  {'title': 'SDE Intern', 'companyName': 'Amazon...
# 44  {'title': 'Graduate Teaching Assistant', 'comp...
# 45  {'title': 'Software Engineer Co-op', 'companyN...
# 46  {'title': 'Application Developer', 'companyNam...
# 47  {'title': 'Software Engineer Intern', 'company...
# 48  {'title': 'Instructional Student Assistant (Pa...
# 49  {'title': 'Software Engineering Intern', 'comp...
# 50  {'title': 'Network Support Engineer', 'company...
# 51  {'title': 'Software Engineer', 'companyName': ...
# 52  {'title': 'Software Development Test Engineer,...
# 53  {'title': 'Software Engineer', 'companyName': ...
# 54  {'title': 'Software Development Intern', 'comp...
# 55  {'title': 'Summer Intern', 'companyName': 'Ver...
# 56  {'title': 'Software Engineer 2, Quality', 'com...
# 57  {'title': 'Instructional Student Assistant', '...
# 58  {'title': 'Data Science Intern', 'companyName'...
# 59  {'title': 'Research Assistant', 'companyName':...
#
#                                            educations  \
# 0   [{'title': 'San Jose State University', 'degre...
# 1   [{'title': 'Northern Illinois University', 'de...
# 2   [{'title': 'San Jose State University', 'degre...
# 3   [{'title': 'San Jose State University', 'degre...
# 4   [{'title': 'San Jose State University', 'degre...
# 5   [{'title': 'San Jose State University', 'degre...
# 6   [{'title': 'San Jose State University', 'degre...
# 7   [{'title': 'San Jose State University', 'degre...
# 8   [{'title': 'Worcester Polytechnic Institute', ...
# 9   [{'title': 'University of Southern California'...
# 10  [{'title': 'Carnegie Mellon University', 'degr...
# 11  [{'title': 'San Jose State University', 'degre...
# 12  [{'title': 'Georgia Institute of Technology', ...
# 13  [{'title': 'University of California San Diego...
# 14  [{'title': 'San Jose State University', 'degre...
# 15  [{'title': 'San Jose State University', 'degre...
# 16  [{'title': 'University of Delaware', 'degree':...
# 17  [{'title': 'San Jose State University', 'degre...
# 18  [{'title': 'San Jose State University', 'degre...
# 19  [{'title': 'San Jose State University', 'degre...
# 20  [{'title': 'San Jose State University', 'degre...
# 21  [{'title': 'San Jose State University', 'degre...
# 22  [{'title': 'Santa Clara University', 'degree':...
# 23  [{'title': 'Columbia University in the City of...
# 24  [{'title': 'San Francisco State University', '...
# 25  [{'title': 'Cornell University', 'degree': 'Ma...
# 26  [{'title': 'Massachusetts Institute of Technol...
# 27  [{'title': 'San Jose State University', 'degre...
# 28  [{'title': 'San Jose State University', 'degre...
# 29  [{'title': 'University of Utah', 'degree': 'Ba...
# 30  [{'title': 'University of Southern California'...
# 31  [{'title': 'Stony Brook University', 'degree':...
# 32  [{'title': 'San Jose State University', 'date1...
# 33  [{'title': 'San Jose State University', 'degre...
# 34  [{'title': 'Columbia University in the City of...
# 35  [{'title': 'San Jose State University', 'degre...
# 36  [{'title': 'University of Illinois at Chicago'...
# 37  [{'title': 'San Jose State University', 'degre...
# 38  [{'title': 'San Jose State University', 'degre...
# 39  [{'title': 'University of North Carolina at Ch...
# 40  [{'title': 'San Jose State University', 'degre...
# 41  [{'title': 'San Jose State University', 'degre...
# 42  [{'title': 'San Jose State University', 'degre...
# 43  [{'title': 'San Jose State University', 'degre...
# 44  [{'title': 'San Jose State University', 'degre...
# 45  [{'title': 'Northeastern University', 'degree'...
# 46  [{'title': 'San Jose State University', 'degre...
# 47  [{'title': 'San Jose State University', 'degre...
# 48  [{'title': 'San Jose State University', 'degre...
# 49  [{'title': 'San Jose State University', 'degre...
# 50  [{'title': 'University of Cincinnati', 'degree...
# 51  [{'title': 'San Jose State University', 'degre...
# 52  [{'title': 'San Jose State University', 'degre...
# 53  [{'title': 'San Jose State University', 'degre...
# 54  [{'title': 'San Jose State University', 'degre...
# 55  [{'title': 'San Jose State University', 'degre...
# 56  [{'title': 'San Jose State University', 'degre...
# 57  [{'title': 'San Jose State University', 'degre...
# 58  [{'title': 'San Jose State University', 'degre...
# 59  [{'title': 'San Jose State University', 'degre...
#
#                                                skills
# 0   {'programming': 14, 'javascript': 10, 'java': ...
# 1   {'java': 4, 'javascript': 4, 'spring': 4, 'web...
# 2   {'java': 102, 'c': 62, 'c#': 28, 'erp': 8, 'ag...
# 3   {'cognos': 2, 'corejava': 54, 'java': 54, 'scr...
# 4   {'java': 16, 'webapplications': 16, 'reactjs':...
# 5   {'oracleebusinesssuite': 8, 'oraclefinancials'...
# 6   {'reactjs': 4, 'java': 6, 'nodejs': 2, 'reduxj...
# 7   {'c': 38, 'algorithms': 36, 'datastructures': ...
# 8   {'c++': 22, 'c': 16, 'microsoftword': 14, 'mic...
# 9   {'c': 38, 'rubyonrails': 16, 'datastructures':...
# 10  {'datastructures': 22, 'c++': 20, 'c': 18, 'al...
# 11  {'c': 2, 'c++': 4, 'java': 2, 'programming': 2...
# 12  {'java': 30, 'androiddevelopment': 16, 'c': 28...
# 13  {'leadership': 6, 'c++': 4, 'c': 4, 'sports': ...
# 14  {'java': 80, 'c++': 58, 'sql': 52, 'softwarede...
# 15  {'neo4j': 8, 'nodejs': 10, 'angularjs': 16, 'p...
# 16  {'databases': 34, 'testing': 34, 'java': 34, '...
# 17  {'javascript': 16, 'angularjs': 14, 'reactjs':...
# 18  {'python': 7, 'devops': 2, 'corejava': 40, 'ag...
# 19  {'embeddedsoftware': 22, 'embeddedc': 20, 'emb...
# 20  {'c++': 10, 'python': 4, 'tcp/ip': 5, 'datastr...
# 21  {'python': 6, 'java': 10, 'c': 8, 'c++': 6, 'm...
# 22  {'webdevelopment': 10, 'c': 8, 'java': 8, 'dat...
# 23  {'corejava': 62, 'sql': 42, 'c': 36, 'software...
# 24  {'programming': 14, 'java': 10, 'html': 4, 'oo...
# 25  {'c': 30, 'algorithms': 30, 'datastructures': ...
# 26  {'batteries': 96, 'fuelcells': 64, 'productdev...
# 27  {'java': 4, 'softwaredesignpatterns': 2, 'clou...
# 28  {'java': 18, 'javascript': 18, 'nodejs': 20, '...
# 29  {'webdevelopment': 2, 'javascript': 2, 'nodejs...
# 30  {'c++': 36, 'java': 32, 'c': 28, 'programming'...
# 31  {'deeplearning': 12, 'computervision': 12, 'ma...
# 32  {'javascript': 4, 'python': 2, 'java': 4, 'tcp...
# 33  {'java': 6, 'c++': 6, 'python': 4, 'oop': 1, '...
# 34           {'research': 16, 'matlab': 8, 'java': 6}
# 35  {'manufacturing': 6, 'doe': 3, 'dataanalysis':...
# 36  {'programmanagement': 2, 'engineering': 20, 'a...
# 37                                                 {}
# 38  {'c++': 80, 'java': 60, 'c': 42, 'algorithms':...
# 39  {'machinelearning': 6, 'deeplearning': 6, 'pyt...
# 40  {'nodejs': 32, 'angularjs': 34, 'mongodb': 32,...
# 41  {'nodejs': 4, 'reactjs': 4, 'python': 2, 'aws'...
# 42  {'machinelearning': 14, 'python': 20, 'c++': 2...
# 43  {'python': 12, 'naturallanguageprocessing': 6,...
# 44  {'html': 12, 'sql': 12, 'microsoftoffice': 12,...
# 45  {'bigdata': 16, 'informationretrieval': 14, 'c...
# 46  {'xml': 40, 'mysql': 36, 'javascript': 34, 'we...
# 47  {'python': 8, 'c++': 10, 'networking': 8, 'pro...
# 48  {'c': 7, 'java': 10, 'c++': 10, 'datastructure...
# 49  {'operatingsystems': 8, 'computernetworking': ...
# 50  {'c': 84, 'microsoftoffice': 76, 'java': 70, '...
# 51  {'java': 30, 'html': 20, 'c': 20, 'programming...
# 52  {'c': 104, 'c++': 98, 'microsoftoffice': 82, '...
# 53  {'python': 20, 'linux': 22, 'gerrit': 6, 'shel...
# 54  {'java': 4, 'python': 3, 'projectmanagement': ...
# 55  {'hadoop': 10, 'nodejs': 12, 'java': 10, 'shel...
# 56  {'java': 18, 'c': 42, 'python': 30, 'networkse...
# 57  {'androiddevelopment': 44, 'java': 44, 'meanst...
# 58  {'c++': 16, 'python': 5, 'r': 2, 'oop': 3, 're...
# 59  {'c++': 28, 'java': 30, 'python': 28, 'android...

# %% [markdown]
# ### Data frame preparation - Keep profiles that are interns

# %%
# Filtering the dataframe to retain only the target position - 'Intern'
intern_df     = jsons_data[(jsons_data['is_intern'] == 1)]

# Adding the targetuser to dataframe
target_df     = jsons_data[(jsons_data['name'] == "Prathamesh Karve")]

prediction_df = pd.concat([intern_df, target_df])

skills_df     = prediction_df['skills'].apply(pd.Series)
skills_df['name'] = jsons_data['name']

# %% [markdown]
# ## Analysis - Collaborative filtering

# %% [markdown]
# ### Get similar profiles

# %%
N = 10
s1 = skills_df.rank(axis=1, method='max', ascending=False)
s2 = skills_df.mask(skills_df.rank(axis=1, method='max', ascending=False) > N, 0)
s2 = s2.fillna(0)
s2 = s2.loc[:, (s2 != 0).any(axis=0)]

for col in s2.columns:
    if len(s2[col].unique()) == 2:
        s2.drop(col,inplace=True, axis=1)
    elif s2[col][57] == 0:
        s2.drop(col,inplace=True, axis=1)
        
import numpy as np
s2 = s2.loc[np.sum(s2.iloc[:,:-1]>0, axis=1)[lambda x: x>=3].index]
s2['name'] = jsons_data['name']

similar_profiles = s2['name'].tolist()

print("Profiles similar to target user Prathamesh Karve are")
for name in similar_profiles:
    print("\n", name)
# Out:
# Profiles similar to target user Prathamesh Karve are
#
#  Saumya
#
#  Amruta
#
#  Sweety
#
#  Riti
#
#  Neha
#
#  Nayana
#
#  Priyanka
#
#  Jacky C.
#
#  Saket
#
#  Anoop
#
#  Ashish
#
#  Prathamesh

# %% [markdown]
# ### Recommend skills based on similar profiles

# %%
s3 = skills_df[~skills_df.index.isin(s2.index)]
for col in s3.columns:
    if col in s2.columns:
        s3.drop(col,inplace=True,axis=1)

s4 = s3.sum()

answer = s4.nlargest(n=10)
answer
# Out:
# datastructures     52.0
# nodejs             48.0
# javascript         46.0
# microsoftoffice    44.0
# corejava           42.0
# mysql              38.0
# reactjs            38.0
# sql                32.0
# mongodb            30.0
# linux              28.0
# dtype: float64
